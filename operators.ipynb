# %%
a=100
b=37
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
# Out:
# 137
# 63
# 3700
# 2.7027027027027026
# 26
# 2

# %%
a=100
b=37
a+=29
print(a)
a-=4
print(a)
a *= 6
print(a)
a*=3
print(a)
a/=20
print(a)
a%=2
print(a)
a=112.5
a//=2
print(a)
a=2
a**=2
print(a)
a&=3
print(a)
# Out:
# 129
# 125
# 750
# 2250
# 112.5
# 0.5
# 56.0
# 4
# 0
