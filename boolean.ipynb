# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)

print(bool("Hello"))
print(bool(15))
# Out:
# True
# False
# False
# True
# True

# %%
class myclass():
  def __len__(self):
    return 0

myobj = myclass()
print(bool(myobj))
# Out:
# False

# %%
def function():
    return True

if function():
    print('hello')
else:
    print('false')
# Out:
# hello
