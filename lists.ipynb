# %%
#List items are ordered, changeable, and allow duplicate values.


thislist = list(("apple", "banana", "cherry")) # note the double round-brackets
print(thislist)

a = list(('a','b,c'))
print(a)

thislist = ["apple", "banana", "cherry"]
print(thislist[-1])

thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:5])
print(thislist[:4])
print(thislist[1:])
thislist[0] = 'arha'
print(thislist)
thislist[0:2]=['hello','arha']
print(thislist)

thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"]
print(thislist)
print(thislist[1])
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']
# ['a', 'b,c']
# cherry
# ['cherry', 'orange', 'kiwi']
# ['apple', 'banana', 'cherry', 'orange']
# ['banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']
# ['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']
# ['hello', 'arha', 'cherry', 'orange', 'kiwi', 'melon', 'mango']
# ['apple', 'blackcurrant', 'watermelon', 'cherry']
# blackcurrant
# ['apple', 'watermelon']

# %%
a=['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']
b='hello'
print(a)
a.extend(b)
print(a)
a.append('mango')
print(a)
(a.remove('mango'))
print(a)
a.pop()
print(a)
a.pop(6)
del a[6]
print(a)
# Out:
# ['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']
# ['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'h', 'e', 'l', 'l', 'o']
# ['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'h', 'e', 'l', 'l', 'o', 'mango']
# ['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'h', 'e', 'l', 'l', 'o', 'mango']
# ['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'h', 'e', 'l', 'l', 'o']
# ['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'l', 'l', 'o']

# %%
a=['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'h', 'e', 'l', 'l', 'o', 'mango']
for i in a:
    print(i)
# Out:
# arha
# banana
# cherry
# orange
# kiwi
# melon
# mango
# h
# e
# l
# l
# o
# mango

# %%
for i in range(len(a)):
    print(a[i])
# Out:
# arha
# banana
# cherry
# orange
# kiwi
# melon
# mango
# h
# e
# l
# l
# o
# mango

# %%
i = 0
while i <len(a):
    print(a[i])
    i+= 1
# Out:
# arha
# banana
# cherry
# orange
# kiwi
# melon
# mango
# h
# e
# l
# l
# o
# mango

# %%
print(a)
b = []
for i in a:
    a.append(i)
print(b)
# Out:
# ['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'h', 'e', 'l', 'l', 'o', 'mango']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 b = []
#       3 for i in a:
# ----> 4     a.append(i)
#       5 print(b)
#
# KeyboardInterrupt:

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
a=['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'h', 'e', 'l', 'l', 'o', 'mango']
print(a)

# b = [i for i in a if 'a' in i ]
b = [i for i in a ]
print(b)
b.sort()
print(b)
b.sort(reverse=True)
print(b)
# Out:
# ['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'h', 'e', 'l', 'l', 'o', 'mango']
# ['arha', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'h', 'e', 'l', 'l', 'o', 'mango']
# ['arha', 'banana', 'cherry', 'e', 'h', 'kiwi', 'l', 'l', 'mango', 'mango', 'melon', 'o', 'orange']
# ['orange', 'o', 'melon', 'mango', 'mango', 'l', 'l', 'kiwi', 'h', 'e', 'cherry', 'banana', 'arha']

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
list3.sort()
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       4 list3 = list1 + list2
#       5 print(list3)
# ----> 6 list3.sort()
#       7 print(list3)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
list1.append('hello')
print(list1)
list1.remove('hello')

print(list1)
list1.pop(3)
print(list1)
list2.clear()
print(list2)
# Out:
# ['a', 'b', 'c', 1, 2, 3]
# ['a', 'b', 'c', 1, 2, 3, 'hello']
# ['a', 'b', 'c', 1, 2, 3]
# ['a', 'b', 'c', 2, 3]
# []

# %% [markdown]
# List items are ordered, changeable, and allow duplicate values.
