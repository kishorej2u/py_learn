# %%
a = 2
match a:
    case 1:
        print('a is 1')
    case 2:
        print('a is 2')
    case _:
        print('no match is found')
# Out:
# a is 2

# %%
a = 100
b = 3
match b:
    case 1 | 2 | 3 if a == 10:
        print('valid')
    case 1 | 2 | 3 if a == 100:
        print('valid100')
    case _:
        print('invalid')
# Out:
# valid100
