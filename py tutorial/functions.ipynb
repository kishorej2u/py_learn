# %%
def kishore():
    print('this is kish function')

kishore()
# Out:
# this is kish function

# %%
kishore()
kishore()
kishore()
# Out:
# this is kish function
# this is kish function
# this is kish function

# %%
def wight_conver(temp):
    kg = 1000 * temp
    return kg

wight_conver(86)
# Out:
# 86000
