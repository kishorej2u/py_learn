# %%
a = {1, 2, 3, 'hello', 'kish', True}
print(a)
# Out:
# {1, 2, 3, 'hello', 'kish'}

# %%
print(len(a))
# Out:
# 5

# %%
thisset = {"apple", "banana", "cherry"}

thisset.add("orange")

print(thisset)
# Out:
# {'cherry', 'banana', 'apple', 'orange'}
