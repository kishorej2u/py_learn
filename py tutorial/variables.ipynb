# %%
a= 5
print(a)
# Out:
# 5

# %%
b='hell '
print(b)
# Out:
# hell

# %%
var = 'hello'
print(var)
# Out:
# hello

# %%
var_ = 'hello'
print(var)
# Out:
# hello

# %%
a,b,c = 'hello', 'guys', 'kishore'
print(a,b,c)
print(a+b+c)
# Out:
# hello guys kishore
# helloguyskishore

# %%
d=5
e=14
print(d+e)

# %%
f='jello'
g=6
print(f,g)
# Out:
# jello 6

# %%
def func():
    global x
    x = 'hello'
    print('this is inside func')
func()
print(x)
# Out:
# hello
